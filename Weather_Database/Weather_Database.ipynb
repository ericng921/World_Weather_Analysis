# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | strezhevoy
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | broome
# Processing Record 6 of Set 1 | carhuaz
# Processing Record 7 of Set 1 | portoferraio
# Processing Record 8 of Set 1 | florianopolis
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | vila franca do campo
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | evensk
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | byron bay
# Processing Record 20 of Set 1 | samana
# Processing Record 21 of Set 1 | ambilobe
# Processing Record 22 of Set 1 | porbandar
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | henties bay
# Processing Record 26 of Set 1 | krasnokamensk
# Processing Record 27 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | izumo
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | lianzhou
# Processing Record 39 of Set 1 | amahai
# Processing Record 40 of Set 1 | mehamn
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | innisfail
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | bouafle
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | udachnyy
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | savannah bight
# Processing Record 10 of Set 2 | jardim
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | chom bung
# City not found. Skipping...
# Processing Record 13 of Set 2 | kita
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | te anau
# Processing Record 18 of Set 2 | kloulklubed
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | port blair
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | nara
# Processing Record 27 of Set 2 | anchorage
# Processing Record 28 of Set 2 | nguruka
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 2 | abu samrah
# Processing Record 35 of Set 2 | inuvik
# Processing Record 36 of Set 2 | trairi
# Processing Record 37 of Set 2 | komsomolskiy
# Processing Record 38 of Set 2 | umm lajj
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | jacqueville
# Processing Record 42 of Set 2 | knysna
# Processing Record 43 of Set 2 | guadix
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | ancud
# Processing Record 48 of Set 2 | tupik
# Processing Record 49 of Set 2 | palauig
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | martil
# Processing Record 3 of Set 3 | kenai
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | ampanihy
# Processing Record 8 of Set 3 | kuloy
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | bay roberts
# Processing Record 11 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 3 | kedrovyy
# Processing Record 13 of Set 3 | haines junction
# Processing Record 14 of Set 3 | quelimane
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | birjand
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | thinadhoo
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | cherdyn
# Processing Record 22 of Set 3 | pumiao
# Processing Record 23 of Set 3 | chapais
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | mahanje
# Processing Record 28 of Set 3 | port hedland
# Processing Record 29 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 3 | monze
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | atherton
# Processing Record 33 of Set 3 | lerwick
# Processing Record 34 of Set 3 | hailar
# Processing Record 35 of Set 3 | pucallpa
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | kingman
# Processing Record 39 of Set 3 | mackenzie
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | tinjah
# City not found. Skipping...
# Processing Record 43 of Set 3 | palenque
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | verdun
# Processing Record 48 of Set 3 | sorland
# Processing Record 49 of Set 3 | husavik
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | nizhniy odes
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | atar
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 6 of Set 4 | bakau
# Processing Record 7 of Set 4 | nouadhibou
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | hudson bay
# Processing Record 10 of Set 4 | ambon
# Processing Record 11 of Set 4 | muzhi
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | zhigansk
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | manta
# Processing Record 18 of Set 4 | palmer
# Processing Record 19 of Set 4 | juneau
# Processing Record 20 of Set 4 | phangnga
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | beloha
# Processing Record 23 of Set 4 | emerald
# Processing Record 24 of Set 4 | fort nelson
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | springdale
# Processing Record 28 of Set 4 | coffs harbour
# Processing Record 29 of Set 4 | ilulissat
# Processing Record 30 of Set 4 | garchitorena
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | luohe
# Processing Record 33 of Set 4 | santiago del estero
# Processing Record 34 of Set 4 | san juan
# Processing Record 35 of Set 4 | sarakhs
# Processing Record 36 of Set 4 | ararat
# Processing Record 37 of Set 4 | oktyabrskoye
# Processing Record 38 of Set 4 | marzuq
# Processing Record 39 of Set 4 | jinxiang
# Processing Record 40 of Set 4 | sompeta
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | sioux lookout
# Processing Record 45 of Set 4 | senneterre
# Processing Record 46 of Set 4 | kodinsk
# Processing Record 47 of Set 4 | farafangana
# Processing Record 48 of Set 4 | north vanlaiphai
# Processing Record 49 of Set 4 | shelburne
# Processing Record 50 of Set 4 | rancho san diego
# Processing Record 1 of Set 5 | soe
# Processing Record 2 of Set 5 | rondonopolis
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | college
# Processing Record 5 of Set 5 | la libertad
# Processing Record 6 of Set 5 | lulea
# Processing Record 7 of Set 5 | alta
# Processing Record 8 of Set 5 | wakkanai
# Processing Record 9 of Set 5 | aasiaat
# Processing Record 10 of Set 5 | rafai
# Processing Record 11 of Set 5 | wemmel
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | mingaora
# Processing Record 14 of Set 5 | maryville
# Processing Record 15 of Set 5 | bhuvanagiri
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | narsaq
# Processing Record 18 of Set 5 | homer
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | osakarovka
# Processing Record 21 of Set 5 | aswan
# Processing Record 22 of Set 5 | coquimbo
# Processing Record 23 of Set 5 | hurghada
# Processing Record 24 of Set 5 | teya
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | reconquista
# Processing Record 29 of Set 5 | itambacuri
# Processing Record 30 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 5 | hithadhoo
# Processing Record 33 of Set 5 | touros
# Processing Record 34 of Set 5 | pecos
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | namwala
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | togur
# Processing Record 39 of Set 5 | zarubino
# Processing Record 40 of Set 5 | arlit
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | rio grande city
# Processing Record 43 of Set 5 | trzacka rastela
# Processing Record 44 of Set 5 | palu
# Processing Record 45 of Set 5 | mezen
# Processing Record 46 of Set 5 | suntar
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | robertson
# Processing Record 49 of Set 5 | lucapa
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | mishelevka
# Processing Record 2 of Set 6 | kuryk
# Processing Record 3 of Set 6 | aksu
# Processing Record 4 of Set 6 | wewak
# Processing Record 5 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 6 | killybegs
# Processing Record 7 of Set 6 | impfondo
# Processing Record 8 of Set 6 | luganville
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | san quintin
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | praia
# Processing Record 14 of Set 6 | port elizabeth
# Processing Record 15 of Set 6 | dahuk
# Processing Record 16 of Set 6 | saint-francois
# Processing Record 17 of Set 6 | road town
# Processing Record 18 of Set 6 | urengoy
# Processing Record 19 of Set 6 | kanniyakumari
# Processing Record 20 of Set 6 | worland
# Processing Record 21 of Set 6 | guerrero negro
# Processing Record 22 of Set 6 | bara
# Processing Record 23 of Set 6 | pallasovka
# Processing Record 24 of Set 6 | eagle pass
# Processing Record 25 of Set 6 | kutum
# Processing Record 26 of Set 6 | chuy
# Processing Record 27 of Set 6 | kidal
# Processing Record 28 of Set 6 | manokwari
# Processing Record 29 of Set 6 | antalaha
# Processing Record 30 of Set 6 | jaguaruna
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | viedma
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | sechura
# Processing Record 36 of Set 6 | moree
# Processing Record 37 of Set 6 | tateyama
# Processing Record 38 of Set 6 | yarada
# Processing Record 39 of Set 6 | ardmore
# Processing Record 40 of Set 6 | waipawa
# Processing Record 41 of Set 6 | quatre cocos
# Processing Record 42 of Set 6 | baghdad
# Processing Record 43 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 6 | beringovskiy
# Processing Record 45 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 46 of Set 6 | avera
# Processing Record 47 of Set 6 | butaritari
# Processing Record 48 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 6 | osmena
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | seymchan
# Processing Record 2 of Set 7 | turukhansk
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | tamiahua
# Processing Record 5 of Set 7 | berdigestyakh
# Processing Record 6 of Set 7 | akropong
# Processing Record 7 of Set 7 | inzhavino
# Processing Record 8 of Set 7 | bairiki
# Processing Record 9 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 7 | kuusamo
# Processing Record 11 of Set 7 | nemuro
# Processing Record 12 of Set 7 | balkanabat
# Processing Record 13 of Set 7 | half moon bay
# Processing Record 14 of Set 7 | irbit
# Processing Record 15 of Set 7 | sarkand
# Processing Record 16 of Set 7 | hobyo
# Processing Record 17 of Set 7 | kushima
# Processing Record 18 of Set 7 | kudahuvadhoo
# Processing Record 19 of Set 7 | diego de almagro
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | jutai
# Processing Record 22 of Set 7 | elliot lake
# Processing Record 23 of Set 7 | pekan
# Processing Record 24 of Set 7 | fortuna
# Processing Record 25 of Set 7 | san juan tepa
# Processing Record 26 of Set 7 | ewo
# Processing Record 27 of Set 7 | lukulu
# Processing Record 28 of Set 7 | hambantota
# Processing Record 29 of Set 7 | porto novo
# Processing Record 30 of Set 7 | meadow lake
# Processing Record 31 of Set 7 | saldanha
# Processing Record 32 of Set 7 | punta alta
# Processing Record 33 of Set 7 | port macquarie
# Processing Record 34 of Set 7 | marolambo
# Processing Record 35 of Set 7 | uruzgan
# Processing Record 36 of Set 7 | kourou
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | ust-ishim
# Processing Record 39 of Set 7 | hofn
# Processing Record 40 of Set 7 | chimoio
# Processing Record 41 of Set 7 | bengkulu
# Processing Record 42 of Set 7 | la ronge
# Processing Record 43 of Set 7 | the valley
# Processing Record 44 of Set 7 | sinnamary
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | saint-georges
# Processing Record 47 of Set 7 | whitehorse
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | muravlenko
# Processing Record 50 of Set 7 | gao
# Processing Record 1 of Set 8 | pires do rio
# Processing Record 2 of Set 8 | abu dhabi
# Processing Record 3 of Set 8 | meghraj
# Processing Record 4 of Set 8 | grand gaube
# Processing Record 5 of Set 8 | isangel
# Processing Record 6 of Set 8 | atambua
# Processing Record 7 of Set 8 | presidente epitacio
# Processing Record 8 of Set 8 | sharan
# Processing Record 9 of Set 8 | quixeramobim
# Processing Record 10 of Set 8 | gushikawa
# Processing Record 11 of Set 8 | miraflores
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | mildura
# Processing Record 15 of Set 8 | temba
# Processing Record 16 of Set 8 | surt
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | ekhabi
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | malkapur
# Processing Record 21 of Set 8 | aljezur
# Processing Record 22 of Set 8 | cockburn town
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | ekibastuz
# Processing Record 25 of Set 8 | champasak
# Processing Record 26 of Set 8 | cuenca
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | takoradi
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | mandiana
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | triesen
# Processing Record 33 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 8 | tulun
# Processing Record 35 of Set 8 | bathsheba
# Processing Record 36 of Set 8 | nioki
# Processing Record 37 of Set 8 | rawson
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | bethel
# Processing Record 40 of Set 8 | orgtrud
# Processing Record 41 of Set 8 | romny
# Processing Record 42 of Set 8 | clifton
# Processing Record 43 of Set 8 | vanimo
# Processing Record 44 of Set 8 | northport
# Processing Record 45 of Set 8 | podor
# Processing Record 46 of Set 8 | batemans bay
# Processing Record 47 of Set 8 | hope
# Processing Record 48 of Set 8 | shuangyang
# Processing Record 49 of Set 8 | shirokiy
# Processing Record 50 of Set 8 | markova
# Processing Record 1 of Set 9 | sinop
# Processing Record 2 of Set 9 | lyuban
# Processing Record 3 of Set 9 | ayagoz
# Processing Record 4 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 9 | parker
# Processing Record 6 of Set 9 | sumenep
# Processing Record 7 of Set 9 | sembakung
# Processing Record 8 of Set 9 | mkushi
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | saint-augustin
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | elat
# Processing Record 14 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 9 | lagoa
# Processing Record 16 of Set 9 | adrar
# Processing Record 17 of Set 9 | sambava
# Processing Record 18 of Set 9 | oranjemund
# Processing Record 19 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 20 of Set 9 | sao joao da barra
# Processing Record 21 of Set 9 | victor harbor
# Processing Record 22 of Set 9 | gorontalo
# Processing Record 23 of Set 9 | zhanakorgan
# Processing Record 24 of Set 9 | saiha
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | formosa
# Processing Record 27 of Set 9 | gorele
# Processing Record 28 of Set 9 | towada
# Processing Record 29 of Set 9 | miyako
# Processing Record 30 of Set 9 | namatanai
# Processing Record 31 of Set 9 | cap-aux-meules
# Processing Record 32 of Set 9 | miles city
# Processing Record 33 of Set 9 | tuatapere
# Processing Record 34 of Set 9 | vestmanna
# Processing Record 35 of Set 9 | novoagansk
# Processing Record 36 of Set 9 | tahoua
# Processing Record 37 of Set 9 | alyangula
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | tessalit
# Processing Record 40 of Set 9 | media luna
# Processing Record 41 of Set 9 | ust-barguzin
# Processing Record 42 of Set 9 | kavieng
# Processing Record 43 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 9 | morant bay
# Processing Record 46 of Set 9 | las palmas
# Processing Record 47 of Set 9 | paoua
# Processing Record 48 of Set 9 | colares
# Processing Record 49 of Set 9 | urucurituba
# Processing Record 50 of Set 9 | imbituba
# Processing Record 1 of Set 10 | gus-zheleznyy
# Processing Record 2 of Set 10 | mayumba
# Processing Record 3 of Set 10 | verkhnetulomskiy
# Processing Record 4 of Set 10 | katsuura
# Processing Record 5 of Set 10 | nizhniy ingash
# Processing Record 6 of Set 10 | forestville
# Processing Record 7 of Set 10 | itaueira
# Processing Record 8 of Set 10 | neryungri
# Processing Record 9 of Set 10 | buala
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | nanortalik
# Processing Record 12 of Set 10 | abha
# Processing Record 13 of Set 10 | verkhnevilyuysk
# Processing Record 14 of Set 10 | port hueneme
# Processing Record 15 of Set 10 | kulhudhuffushi
# Processing Record 16 of Set 10 | tiznit
# Processing Record 17 of Set 10 | raudeberg
# Processing Record 18 of Set 10 | havelock
# Processing Record 19 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | tura
# Processing Record 22 of Set 10 | praya
# Processing Record 23 of Set 10 | madang
# Processing Record 24 of Set 10 | hamilton
# Processing Record 25 of Set 10 | yeniseysk
# Processing Record 26 of Set 10 | pocone
# Processing Record 27 of Set 10 | saucillo
# Processing Record 28 of Set 10 | plettenberg bay
# Processing Record 29 of Set 10 | kinkala
# Processing Record 30 of Set 10 | borba
# Processing Record 31 of Set 10 | pincher creek
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | acarau
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | pacific grove
# Processing Record 36 of Set 10 | suez
# Processing Record 37 of Set 10 | kahului
# Processing Record 38 of Set 10 | goya
# Processing Record 39 of Set 10 | canutama
# Processing Record 40 of Set 10 | sao felix do xingu
# Processing Record 41 of Set 10 | usinsk
# Processing Record 42 of Set 10 | keetmanshoop
# Processing Record 43 of Set 10 | severo-yeniseyskiy
# Processing Record 44 of Set 10 | taitung
# Processing Record 45 of Set 10 | koshurnikovo
# Processing Record 46 of Set 10 | xingcheng
# Processing Record 47 of Set 10 | los llanos de aridane
# Processing Record 48 of Set 10 | athens
# Processing Record 49 of Set 10 | okhotsk
# Processing Record 50 of Set 10 | vostochnyy
# Processing Record 1 of Set 11 | anderson
# Processing Record 2 of Set 11 | susanville
# Processing Record 3 of Set 11 | geilo
# Processing Record 4 of Set 11 | ozernovskiy
# Processing Record 5 of Set 11 | ponta delgada
# Processing Record 6 of Set 11 | salalah
# Processing Record 7 of Set 11 | grindavik
# Processing Record 8 of Set 11 | virginia beach
# Processing Record 9 of Set 11 | la victoria
# Processing Record 10 of Set 11 | brewster
# Processing Record 11 of Set 11 | baherden
# Processing Record 12 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 11 | aleksandrov gay
# Processing Record 14 of Set 11 | itarema
# Processing Record 15 of Set 11 | hovd
# Processing Record 16 of Set 11 | saurimo
# Processing Record 17 of Set 11 | zaozerne
# Processing Record 18 of Set 11 | santa adelia
# Processing Record 19 of Set 11 | qasigiannguit
# Processing Record 20 of Set 11 | clovis
# Processing Record 21 of Set 11 | trat
# Processing Record 22 of Set 11 | mount isa
# Processing Record 23 of Set 11 | caconda
# Processing Record 24 of Set 11 | theodoriana
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | valdemarpils
# Processing Record 27 of Set 11 | pizarro
# Processing Record 28 of Set 11 | puerto del rosario
# Processing Record 29 of Set 11 | honiara
# Processing Record 30 of Set 11 | bubaque
# Processing Record 31 of Set 11 | panama city
# Processing Record 32 of Set 11 | ust-nera
# Processing Record 33 of Set 11 | pangnirtung
# Processing Record 34 of Set 11 | burica
# City not found. Skipping...
# Processing Record 35 of Set 11 | inhambane
# Processing Record 36 of Set 11 | vega de alatorre
# Processing Record 37 of Set 11 | mokrousovo
# Processing Record 38 of Set 11 | kinablangan
# Processing Record 39 of Set 11 | santa fe
# Processing Record 40 of Set 11 | chipinge
# Processing Record 41 of Set 11 | manoel urbano
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | paragould
# Processing Record 44 of Set 11 | eskil
# Processing Record 45 of Set 11 | santa rosa
# Processing Record 46 of Set 11 | bonavista
# Processing Record 47 of Set 11 | tucuman
# Processing Record 48 of Set 11 | kishi
# Processing Record 49 of Set 11 | sistranda
# Processing Record 50 of Set 11 | mantua
# Processing Record 1 of Set 12 | ocean city
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | dicabisagan
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 12 | lemgo
# Processing Record 7 of Set 12 | molochnoye
# Processing Record 8 of Set 12 | birao
# Processing Record 9 of Set 12 | gumdag
# Processing Record 10 of Set 12 | la union
# Processing Record 11 of Set 12 | vorobyevka
# Processing Record 12 of Set 12 | tual
# Processing Record 13 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 12 | maningrida
# Processing Record 16 of Set 12 | srednekolymsk
# Processing Record 17 of Set 12 | aykhal
# Processing Record 18 of Set 12 | uchiza
# Processing Record 19 of Set 12 | maiduguri
# Processing Record 20 of Set 12 | mana
# Processing Record 21 of Set 12 | panormos
# Processing Record 22 of Set 12 | darnah
# Processing Record 23 of Set 12 | ruteng
# Processing Record 24 of Set 12 | liepaja
# Processing Record 25 of Set 12 | luangwa
# Processing Record 26 of Set 12 | cascais
# Processing Record 27 of Set 12 | igurubi
# Processing Record 28 of Set 12 | agustin codazzi
# Processing Record 29 of Set 12 | clyde
# Processing Record 30 of Set 12 | opotiki
# Processing Record 31 of Set 12 | puerto narino
# Processing Record 32 of Set 12 | dali
# Processing Record 33 of Set 12 | madingou
# Processing Record 34 of Set 12 | san nicolas
# Processing Record 35 of Set 12 | luderitz
# Processing Record 36 of Set 12 | puerto leguizamo
# Processing Record 37 of Set 12 | khetri
# Processing Record 38 of Set 12 | beyneu
# Processing Record 39 of Set 12 | bouna
# Processing Record 40 of Set 12 | berlevag
# Processing Record 41 of Set 12 | fuyang
# Processing Record 42 of Set 12 | kirovskaya
# Processing Record 43 of Set 12 | progreso
# Processing Record 44 of Set 12 | tolaga bay
# Processing Record 45 of Set 12 | duluth
# Processing Record 46 of Set 12 | urubicha
# Processing Record 47 of Set 12 | selfoss
# Processing Record 48 of Set 12 | pergamino
# Processing Record 49 of Set 12 | conde
# Processing Record 50 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 1 of Set 13 | noumea
# Processing Record 2 of Set 13 | yerbogachen
# Processing Record 3 of Set 13 | kathu
# Processing Record 4 of Set 13 | northam
# Processing Record 5 of Set 13 | buluang
# Processing Record 6 of Set 13 | luebo
# Processing Record 7 of Set 13 | macklin
# Processing Record 8 of Set 13 | verkh-usugli
# Processing Record 9 of Set 13 | felanitx
# Processing Record 10 of Set 13 | corn island
# Processing Record 11 of Set 13 | lasa
# Processing Record 12 of Set 13 | trincomalee
# Processing Record 13 of Set 13 | kemijarvi
# Processing Record 14 of Set 13 | bilma
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | vila do maio
# Processing Record 17 of Set 13 | taos
# Processing Record 18 of Set 13 | natal
# Processing Record 19 of Set 13 | inta
# Processing Record 20 of Set 13 | jinchang
# Processing Record 21 of Set 13 | sosnovo-ozerskoye
# Processing Record 22 of Set 13 | butembo
# Processing Record 23 of Set 13 | piranhas
# Processing Record 24 of Set 13 | brae
# Processing Record 25 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 13 | barreirinha
# Processing Record 27 of Set 13 | vysokogornyy
# Processing Record 28 of Set 13 | zyryanka
# Processing Record 29 of Set 13 | enshi
# Processing Record 30 of Set 13 | beian
# Processing Record 31 of Set 13 | arroyo
# Processing Record 32 of Set 13 | tilichiki
# Processing Record 33 of Set 13 | salinopolis
# Processing Record 34 of Set 13 | praia da vitoria
# Processing Record 35 of Set 13 | conceicao do araguaia
# Processing Record 36 of Set 13 | havre-saint-pierre
# Processing Record 37 of Set 13 | yen bai
# Processing Record 38 of Set 13 | harlingen
# Processing Record 39 of Set 13 | qianguo
# Processing Record 40 of Set 13 | meulaboh
# Processing Record 41 of Set 13 | sobolevo
# Processing Record 42 of Set 13 | champerico
# Processing Record 43 of Set 13 | baykit
# Processing Record 44 of Set 13 | hervey bay
# Processing Record 45 of Set 13 | kingston
# Processing Record 46 of Set 13 | la plata
# Processing Record 47 of Set 13 | omboue
# Processing Record 48 of Set 13 | heilbron
# Processing Record 49 of Set 13 | ugoofaaru
# Processing Record 50 of Set 13 | trinidad
# Processing Record 1 of Set 14 | doha
# Processing Record 2 of Set 14 | oakley
# Processing Record 3 of Set 14 | belmonte
# Processing Record 4 of Set 14 | wooster
# Processing Record 5 of Set 14 | guaraniacu
# Processing Record 6 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 14 | oussouye
# Processing Record 8 of Set 14 | nhulunbuy
# Processing Record 9 of Set 14 | proletarsk
# Processing Record 10 of Set 14 | hillsborough
# Processing Record 11 of Set 14 | acapulco
# Processing Record 12 of Set 14 | bloemfontein
# Processing Record 13 of Set 14 | xai-xai
# Processing Record 14 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 14 | altay
# Processing Record 17 of Set 14 | sijunjung
# Processing Record 18 of Set 14 | jaguey grande
# Processing Record 19 of Set 14 | bandundu
# Processing Record 20 of Set 14 | tiarei
# Processing Record 21 of Set 14 | tromso
# Processing Record 22 of Set 14 | pochutla
# Processing Record 23 of Set 14 | tabas
# Processing Record 24 of Set 14 | elista
# Processing Record 25 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 26 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 14 | makushino
# Processing Record 28 of Set 14 | matera
# Processing Record 29 of Set 14 | matagami
# Processing Record 30 of Set 14 | maksatikha
# Processing Record 31 of Set 14 | valley city
# Processing Record 32 of Set 14 | senanga
# Processing Record 33 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 34 of Set 14 | ulaangom
# Processing Record 35 of Set 14 | cairns
# Processing Record 36 of Set 14 | petatlan
# Processing Record 37 of Set 14 | buraydah
# Processing Record 38 of Set 14 | qabis
# City not found. Skipping...
# Processing Record 39 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 40 of Set 14 | tsiroanomandidy
# Processing Record 41 of Set 14 | djibo
# Processing Record 42 of Set 14 | heihe
# Processing Record 43 of Set 14 | naberera
# Processing Record 44 of Set 14 | nurmahal
# Processing Record 45 of Set 14 | teguise
# Processing Record 46 of Set 14 | zabaykalsk
# Processing Record 47 of Set 14 | ola
# Processing Record 48 of Set 14 | miracema do tocantins
# Processing Record 49 of Set 14 | eureka
# Processing Record 50 of Set 14 | twentynine palms
# Processing Record 1 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 15 | madimba
# Processing Record 3 of Set 15 | bismarck
# Processing Record 4 of Set 15 | gravdal
# Processing Record 5 of Set 15 | athabasca
# Processing Record 6 of Set 15 | huanren
# Processing Record 7 of Set 15 | kieta
# Processing Record 8 of Set 15 | balakhninskiy
# Processing Record 9 of Set 15 | kasane
# Processing Record 10 of Set 15 | olafsvik
# Processing Record 11 of Set 15 | houma
# Processing Record 12 of Set 15 | najran
# Processing Record 13 of Set 15 | cananeia
# Processing Record 14 of Set 15 | demyansk
# Processing Record 15 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 16 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 15 | mocuba
# Processing Record 18 of Set 15 | mae sai
# Processing Record 19 of Set 15 | grozesti
# Processing Record 20 of Set 15 | la asuncion
# Processing Record 21 of Set 15 | mayo
# Processing Record 22 of Set 15 | kalmunai
# Processing Record 23 of Set 15 | aksarayskiy
# Processing Record 24 of Set 15 | haverfordwest
# Processing Record 25 of Set 15 | kalomo
# City not found. Skipping...
# Processing Record 26 of Set 15 | elk city
# Processing Record 27 of Set 15 | aketi
# Processing Record 28 of Set 15 | craigieburn
# Processing Record 29 of Set 15 | ayan
# Processing Record 30 of Set 15 | bestobe
# Processing Record 31 of Set 15 | nerchinskiy zavod
# Processing Record 32 of Set 15 | laiagam
# City not found. Skipping...
# Processing Record 33 of Set 15 | havoysund
# Processing Record 34 of Set 15 | tarakan
# Processing Record 35 of Set 15 | tokur
# Processing Record 36 of Set 15 | kitakami
# Processing Record 37 of Set 15 | karaton
# Processing Record 38 of Set 15 | north myrtle beach
# Processing Record 39 of Set 15 | rypefjord
# Processing Record 40 of Set 15 | aquiraz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Strezhevoy  60.7333   77.5889     23.77        97          85
# 1    New Norfolk -42.7826  147.0587     47.71        83          18
# 2        Rikitea -23.1203 -134.9692     79.41        71           7
# 3         Albany  42.6001  -73.9662     47.64        91         100
# 4         Broome  42.2506  -75.8330     48.38        83         100
# 5        Carhuaz  -9.2819  -77.6447     64.53        73          98
# 6   Portoferraio  42.8115   10.3146     56.52        79           8
# 7  Florianopolis -27.6146  -48.5012     72.70        78          75
# 8      Busselton -33.6500  115.3333     63.84        64          85
# 9    East London -33.0153   27.9116     61.48        64          18
#
#    Wind Speed Country Current Description
# 0        4.74      RU          light snow
# 1        2.48      AU          few clouds
# 2       15.84      PF           clear sky
# 3       10.00      US       moderate rain
# 4        1.01      US       moderate rain
# 5        2.44      PE          light rain
# 6       14.12      IT           clear sky
# 7        6.91      BR       broken clouds
# 8        7.05      AU     overcast clouds
# 9       16.28      ZA          few clouds

# %%
#recorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Strezhevoy      RU  60.7333   77.5889     23.77        97          85
# 1    New Norfolk      AU -42.7826  147.0587     47.71        83          18
# 2        Rikitea      PF -23.1203 -134.9692     79.41        71           7
# 3         Albany      US  42.6001  -73.9662     47.64        91         100
# 4         Broome      US  42.2506  -75.8330     48.38        83         100
# 5        Carhuaz      PE  -9.2819  -77.6447     64.53        73          98
# 6   Portoferraio      IT  42.8115   10.3146     56.52        79           8
# 7  Florianopolis      BR -27.6146  -48.5012     72.70        78          75
# 8      Busselton      AU -33.6500  115.3333     63.84        64          85
# 9    East London      ZA -33.0153   27.9116     61.48        64          18
#
#    Wind Speed Current Description
# 0        4.74          light snow
# 1        2.48          few clouds
# 2       15.84           clear sky
# 3       10.00       moderate rain
# 4        1.01       moderate rain
# 5        2.44          light rain
# 6       14.12           clear sky
# 7        6.91       broken clouds
# 8        7.05     overcast clouds
# 9       16.28          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
